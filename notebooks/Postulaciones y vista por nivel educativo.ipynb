# %%
#importaciones
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import _converter
# %matplotlib inline 
plt.style.use('default') # haciendo los graficos un poco mas bonitos en matplotlib
#plt.rcParams['figure.figsize'] = (20, 10)
import datetime
sns.set(style="whitegrid") # seteando tipo de grid en seaborn
# %matplotlib inline
# Out:
# <style>.container { width:90% !important; }</style>

# %%
df_edu = pd.read_csv("../datos_navent_fiuba/fiuba_1_postulantes_educacion.csv")
df_gen_edad = pd.read_csv("../datos_navent_fiuba/fiuba_2_postulantes_genero_y_edad.csv", parse_dates=['fechanacimiento'])
df_vistas = pd.read_csv("../datos_navent_fiuba/fiuba_3_vistas.csv", parse_dates=['timestamp'])
df_postulaciones = pd.read_csv("../datos_navent_fiuba/fiuba_4_postulaciones.csv", parse_dates=['fechapostulacion'])

df_vistas["date"] = df_vistas["timestamp"].dt.date
df_postulaciones["date"] = df_vistas["timestamp"].dt.date
date_ini = datetime.date(year=2018,month=2,day=23)
date_fin = datetime.date(year=2018,month=2,day=28)
df_periodo_postulaciones = df_postulaciones[df_postulaciones["date"] >= date_ini]
df_periodo_vistas = df_vistas[(df_vistas["date"] >= date_ini) & (df_vistas["date"] <= date_fin)]

# %%
orden_nombre = {
    "Doctorado":0,
    "Master":1,
    "Posgrado":2,
    "Universitario":3,
    "Terciario/Técnico":4,
    "Secundario":5,
    "Otro":6
}

orden_estado = {
    "Graduado":0,
    "En Curso":1,
    "Abandonado":2,
}

df_edu["prioridad_nom"] = df_edu["nombre"].apply(lambda nombre: orden_nombre.get(nombre))
df_edu["prioridad_est"] = df_edu["estado"].apply(lambda estado: orden_estado.get(estado))

df_edu.sort_values(by= ["idpostulante","prioridad_est","prioridad_nom"],inplace= True)

df_edu_unicos_max = df_edu.drop_duplicates(subset = "idpostulante",keep= "first")


#df_sum_post = df_periodo_postulaciones.groupby("idpostulante")["postulacion"].count()

#df_sum_vista =  df_periodo_vistas.groupby("idpostulante")["vista"].sum().reset_index()

#df_edu_post = df_edu_unicos_max.merge(df_sum_post, on="idpostulante" ,how="inner").groupby("nombre")["postulacion",].sum().reset_index()

#df_edu_vista = df_edu_unicos_max.merge(df_sum_vista, on="idpostulante" ,how="left").groupby("nombre")["vista",].sum().reset_index()

# %%
df_periodo_vistas.drop_duplicates(subset = "idpostulante",keep= "first").shape
# Out:
# (85497, 4)

# %%
df_sum_vistas= df_periodo_vistas.groupby("idpostulante")["idAviso",].count().reset_index()
df_sum_vistas.rename(columns= {"idAviso" : "Vistas"}, inplace=True)

# %%
df_periodo_postulaciones.drop_duplicates(subset = "idpostulante",keep= "first").shape
# Out:
# (54547, 4)

# %%
print "vistas",df_periodo_vistas.shape
print "postulaciones",df_periodo_postulaciones.shape
# Out:
# vistas (921074, 4)
# postulaciones (961897, 4)

# %%
df_sum_post= df_periodo_postulaciones.groupby("idpostulante")["idaviso",].count().reset_index()
df_sum_post.rename(columns= {"idaviso" : "Postulaciones"}, inplace=True)

# %%
#ruzo las vistas
df_edu_vistas = df_edu_unicos_max.join(df_sum_vistas.set_index('idpostulante'),on="idpostulante", how= "inner")

# %%
df_edu_vistas
# Out:
#        idpostulante             nombre      estado  prioridad_nom  \
# 113675      0zB026d  Terciario/Técnico    Graduado              4
# 113857      0zB03O9         Secundario    Graduado              5
# 111181      0zB0YGv               Otro    En Curso              6
# 111191      0zB0xL1      Universitario    En Curso              3
# 121371      0zB11wr      Universitario    Graduado              3
# 121396      0zB16Dr         Secundario    Graduado              5
# 121139      0zB1Bev         Secundario    Graduado              5
# 121559      0zB1XB1         Secundario    Graduado              5
# 121419      0zB1YOY         Secundario    Graduado              5
# 121350      0zB1oA1      Universitario    Graduado              3
# 114447      0zB2Nva         Secundario    Graduado              5
# 116436      0zB2VOa  Terciario/Técnico    Graduado              4
# 116231      0zB2pbr         Secundario    Graduado              5
# 114457      0zB2qQ9         Secundario    Graduado              5
# 111435      0zB2zpr      Universitario    En Curso              3
# 131091      0zB3NPd         Secundario    Graduado              5
# 131085      0zB3Nz9      Universitario    Graduado              3
# 131223      0zB3QQr         Secundario    Graduado              5
# 131052      0zB3laq         Secundario    Graduado              5
# 129095      0zB3zRa      Universitario    En Curso              3
# 104996      0zB4EoY         Secundario    Graduado              5
# 104934      0zB4Lbd         Secundario    Graduado              5
# 102176      0zB4dN9  Terciario/Técnico    En Curso              4
# 105275      0zB4jvq      Universitario    Graduado              3
# 104793      0zB4wYr         Secundario    Graduado              5
# 105186      0zB4xvv         Secundario    Graduado              5
# 111564      0zB5M9v           Posgrado    Graduado              2
# 114500      0zB5VQr  Terciario/Técnico  Abandonado              4
# 111619      0zB5XP8  Terciario/Técnico    Graduado              4
# 111644      0zB5v8q         Secundario    Graduado              5
# ...             ...                ...         ...            ...
# 228008      zvxq2oE      Universitario    Graduado              3
# 228011      zvxq2rJ      Universitario    Graduado              3
# 228493      zvxqJ9m         Secundario    Graduado              5
# 228092      zvxqa1D         Secundario    Graduado              5
# 232142      zvxr0P3      Universitario    Graduado              3
# 232472      zvxrAzJ         Secundario    Graduado              5
# 232180      zvxrKzD         Secundario    Graduado              5
# 232202      zvxrQbb             Master    Graduado              1
# 232486      zvxrrj3         Secundario    Graduado              5
# 230402      zvxrwZb  Terciario/Técnico    En Curso              4
# 201659      zvxv3m3  Terciario/Técnico    Graduado              4
# 198676      zvxv42D      Universitario    En Curso              3
# 198771      zvxv5vE  Terciario/Técnico    En Curso              4
# 202173      zvxv63m      Universitario  Abandonado              3
# 201622      zvxv8JJ         Secundario    Graduado              5
# 203696      zvxvApE         Secundario    Graduado              5
# 203679      zvxvo6J         Secundario    Graduado              5
# 203691      zvxvoJ3  Terciario/Técnico    Graduado              4
# 206530      zvxvr1D      Universitario  Abandonado              3
# 205533      zvxwAlJ      Universitario    Graduado              3
# 206751      zvxwNr6  Terciario/Técnico  Abandonado              4
# 205245      zvxwar6         Secundario    Graduado              5
# 206197      zvxxKwb         Secundario    Graduado              5
# 206149      zvxxaE8         Secundario    Graduado              5
# 206337      zvxxj2E         Secundario    Graduado              5
# 211812      zvxz5rE      Universitario    En Curso              3
# 211816      zvxz9p5  Terciario/Técnico    En Curso              4
# 213712      zvxzJr3      Universitario    Graduado              3
# 213648      zvxzVr8         Secundario    Graduado              5
# 213624      zvxzjoK         Secundario    Graduado              5
#
#         prioridad_est  Vistas
# 113675              0       6
# 113857              0      45
# 111181              1       2
# 111191              1       2
# 121371              0       1
# 121396              0       5
# 121139              0       7
# 121559              0      16
# 121419              0       8
# 121350              0       7
# 114447              0      86
# 116436              0       5
# 116231              0       9
# 114457              0      11
# 111435              1       1
# 131091              0       4
# 131085              0      60
# 131223              0       5
# 131052              0      20
# 129095              1      10
# 104996              0       5
# 104934              0      38
# 102176              1       4
# 105275              0       4
# 104793              0      19
# 105186              0      51
# 111564              0       1
# 114500              2      12
# 111619              0      15
# 111644              0      32
# ...               ...     ...
# 228008              0      36
# 228011              0      21
# 228493              0       9
# 228092              0       1
# 232142              0       4
# 232472              0       8
# 232180              0       4
# 232202              0      13
# 232486              0      55
# 230402              1      24
# 201659              0       9
# 198676              1      59
# 198771              1       1
# 202173              2       2
# 201622              0       5
# 203696              0      24
# 203679              0       4
# 203691              0      16
# 206530              2       1
# 205533              0       3
# 206751              2       8
# 205245              0      11
# 206197              0      30
# 206149              0      23
# 206337              0       1
# 211812              1       8
# 211816              1      20
# 213712              0       2
# 213648              0       2
# 213624              0       2
#
# [80440 rows x 6 columns]

# %%
#cruzo las postulaciones 
df_edu_vistas_post = df_edu_vistas.join(df_sum_post.set_index('idpostulante'),on="idpostulante", how= "inner")

# %%
df_edu_vistas_post
# Out:
#        idpostulante             nombre      estado  prioridad_nom  \
# 113675      0zB026d  Terciario/Técnico    Graduado              4
# 111181      0zB0YGv               Otro    En Curso              6
# 104996      0zB4EoY         Secundario    Graduado              5
# 104934      0zB4Lbd         Secundario    Graduado              5
# 102176      0zB4dN9  Terciario/Técnico    En Curso              4
# 105275      0zB4jvq      Universitario    Graduado              3
# 104793      0zB4wYr         Secundario    Graduado              5
# 105186      0zB4xvv         Secundario    Graduado              5
# 122405      0zB60YY         Secundario    Graduado              5
# 122760      0zB68qq         Secundario    Graduado              5
# 122451      0zB695v  Terciario/Técnico    Graduado              4
# 122581      0zB6KOM         Secundario    Graduado              5
# 122583      0zB6Kxd             Master    Graduado              1
# 122486      0zB6Rd8  Terciario/Técnico    Graduado              4
# 120268      0zB6jJr      Universitario    En Curso              3
# 122301      0zB6qGa      Universitario    Graduado              3
# 137060      0zB83rq         Secundario    Graduado              5
# 117751      0zB9oJ9           Posgrado    Graduado              2
# 127979      0zBMGD1         Secundario    Graduado              5
# 127839      0zBMQo1         Secundario    Graduado              5
# 127891      0zBMoW1         Secundario    Graduado              5
# 120312      0zBO4Vv         Secundario    En Curso              5
# 123066      0zBO9z8      Universitario    Graduado              3
# 120438      0zBOQDv      Universitario    En Curso              3
# 123140      0zBOpwY      Universitario    Graduado              3
# 123248      0zBOxNa  Terciario/Técnico    Graduado              4
# 120510      0zBOxPY      Universitario    En Curso              3
# 113233      0zBP0J9  Terciario/Técnico    Graduado              4
# 113493      0zBP8mY         Secundario    Graduado              5
# 113357      0zBPK21         Secundario    Graduado              5
# ...             ...                ...         ...            ...
# 215684      zvxMz8b         Secundario    Graduado              5
# 227643      zvxXMdm      Universitario    Graduado              3
# 227651      zvxXZ3m  Terciario/Técnico    Graduado              4
# 229840      zvxXv9k      Universitario  Abandonado              3
# 227412      zvxXxGk         Secundario    Graduado              5
# 199174      zvxYVxk         Secundario    Graduado              5
# 199232      zvxYXG3  Terciario/Técnico    Graduado              4
# 206483      zvxad2k      Universitario    Graduado              3
# 208282      zvxazOD      Universitario    Graduado              3
# 219817      zvxj9Bk         Secundario    Graduado              5
# 219607      zvxjBbJ      Universitario    Graduado              3
# 219733      zvxjLXE         Secundario    Graduado              5
# 219768      zvxjQZJ         Secundario    Graduado              5
# 232558      zvxk8Y8         Secundario    Graduado              5
# 230696      zvxkeM5      Universitario    En Curso              3
# 232472      zvxrAzJ         Secundario    Graduado              5
# 232202      zvxrQbb             Master    Graduado              1
# 232486      zvxrrj3         Secundario    Graduado              5
# 201659      zvxv3m3  Terciario/Técnico    Graduado              4
# 198676      zvxv42D      Universitario    En Curso              3
# 198771      zvxv5vE  Terciario/Técnico    En Curso              4
# 202173      zvxv63m      Universitario  Abandonado              3
# 201622      zvxv8JJ         Secundario    Graduado              5
# 203696      zvxvApE         Secundario    Graduado              5
# 203679      zvxvo6J         Secundario    Graduado              5
# 203691      zvxvoJ3  Terciario/Técnico    Graduado              4
# 206530      zvxvr1D      Universitario  Abandonado              3
# 206197      zvxxKwb         Secundario    Graduado              5
# 206149      zvxxaE8         Secundario    Graduado              5
# 206337      zvxxj2E         Secundario    Graduado              5
#
#         prioridad_est  Vistas  Postulaciones
# 113675              0       6              3
# 111181              1       2             51
# 104996              0       5             55
# 104934              0      38             93
# 102176              1       4              1
# 105275              0       4              2
# 104793              0      19             18
# 105186              0      51             25
# 122405              0      13              7
# 122760              0      18              6
# 122451              0       4             25
# 122581              0       7             42
# 122583              0       3              2
# 122486              0       1              8
# 120268              1       3              7
# 122301              0      20             15
# 137060              0       4             36
# 117751              0       2              7
# 127979              0       4             23
# 127839              0      19             44
# 127891              0       3             10
# 120312              1      12              7
# 123066              0      16              3
# 120438              1      34             18
# 123140              0       5              1
# 123248              0       2              2
# 120510              1      21             10
# 113233              0       3              5
# 113493              0       7             17
# 113357              0       5             35
# ...               ...     ...            ...
# 215684              0       7            145
# 227643              0       6             10
# 227651              0      19             26
# 229840              2      11             12
# 227412              0      26              7
# 199174              0       4             17
# 199232              0       9              5
# 206483              0       1             10
# 208282              0       3             11
# 219817              0       3              7
# 219607              0       4             12
# 219733              0       3              1
# 219768              0      17             50
# 232558              0       7              5
# 230696              1      10             12
# 232472              0       8             23
# 232202              0      13              7
# 232486              0      55             21
# 201659              0       9              4
# 198676              1      59             44
# 198771              1       1             11
# 202173              2       2             58
# 201622              0       5             15
# 203696              0      24              2
# 203679              0       4              4
# 203691              0      16             18
# 206530              2       1              5
# 206197              0      30             14
# 206149              0      23             34
# 206337              0       1              1
#
# [21731 rows x 7 columns]

# %% [markdown]
# hay muchos maaas de postulaciones que vistas

# %%
df_edu_vistas_post = df_edu_vistas_post.groupby("nombre")["Vistas","Postulaciones"].sum()
df_edu_vistas_post
# Out:
#                    Vistas  Postulaciones
# nombre
# Doctorado             138            334
# Master               2214           4930
# Otro                 3828           6727
# Posgrado             5007          11206
# Secundario         108580         202671
# Terciario/Técnico   34266          62005
# Universitario       78699         152373

# %%
total_vistas = float(df_edu_vistas_post["Vistas"].sum())
total_postulaciones = float(df_edu_vistas_post["Postulaciones"].sum())

# %%
df_edu_vistas_post["%Vistas"] = df_edu_vistas_post["Vistas"].apply(lambda x: round(x/total_vistas*100))
df_edu_vistas_post["%Postulaciones"] = df_edu_vistas_post["Postulaciones"].apply(lambda x: round(x/total_postulaciones*100))

df_edu_vistas_post= df_edu_vistas_post.reset_index()

df_edu_vistas_post["prioridad"]= df_edu_vistas_post["nombre"].apply(lambda nom: orden_nombre.get(nom))
df_edu_vistas_post = df_edu_vistas_post.sort_values(by= "prioridad",ascending= False)
df_edu_vistas_post = df_edu_vistas_post.set_index(keys="nombre")

# %%
g = df_edu_vistas_post[["%Vistas","%Postulaciones"]].plot(kind="bar", rot= 70)
g.set_title("Distribucion Postulaciones vs Vistas", fontsize=18)
g.set_xlabel("Nivel Educativo", fontsize=12)
g.set_ylabel("Promedio", fontsize=12)
# Out:
# Text(0,0.5,'Promedio')

# %%
df_edu_vistas_post
# Out:
#                    Vistas  Postulaciones  %Vistas  %Postulaciones  prioridad
# nombre
# Otro                 3828           6727      2.0             2.0          6
# Secundario         108580         202671     47.0            46.0          5
# Terciario/Técnico   34266          62005     15.0            14.0          4
# Universitario       78699         152373     34.0            35.0          3
# Posgrado             5007          11206      2.0             3.0          2
# Master               2214           4930      1.0             1.0          1
# Doctorado             138            334      0.0             0.0          0
